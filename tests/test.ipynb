# %%
pip install streamlit streamlit-webrtc opencv-python av
# Out:
# Requirement already satisfied: streamlit in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (1.58.0)
# Requirement already satisfied: streamlit-webrtc in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (0.72.1)
# Requirement already satisfied: opencv-python in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (4.13.0.92)
# Requirement already satisfied: av in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (16.1.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.1.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<8,>=5.5 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (8.4.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (3.1.50)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.2.6)
# Requirement already satisfied: packaging>=20 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (26.2)
# Requirement already satisfied: pandas<4,>=1.4.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.3.3)
# Requirement already satisfied: pillow<13,>=7.1.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (12.2.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.9.2)
# Requirement already satisfied: protobuf<8,>=3.20 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.33.5)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (24.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.34.2)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (9.1.4)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.15.0)
# Requirement already satisfied: starlette>=0.40.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (1.2.1)
# Requirement already satisfied: uvicorn>=0.30.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.49.0)
# Requirement already satisfied: httptools>=0.6.3 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.8.0)
# Requirement already satisfied: anyio>=4.0.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (4.13.0)
# Requirement already satisfied: python-multipart>=0.0.10 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (0.0.30)
# Requirement already satisfied: websockets>=12.0.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (15.0.1)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (2.2.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit) (6.0.0)
# Requirement already satisfied: jinja2 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=2.4.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.22.0)
# Requirement already satisfied: colorama in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from pandas<4,>=1.4.0->streamlit) (2026.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.27->streamlit) (2026.5.20)
# Requirement already satisfied: aioice>=0.10.1 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit-webrtc) (0.10.2)
# Requirement already satisfied: aiortc>=1.14.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from streamlit-webrtc) (1.14.0)
# Requirement already satisfied: dnspython>=2.0.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from aioice>=0.10.1->streamlit-webrtc) (2.8.0)
# Requirement already satisfied: ifaddr>=0.2.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from aioice>=0.10.1->streamlit-webrtc) (0.2.0)
# Requirement already satisfied: cryptography>=44.0.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from aiortc>=1.14.0->streamlit-webrtc) (48.0.0)
# Requirement already satisfied: google-crc32c>=1.1 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from aiortc>=1.14.0->streamlit-webrtc) (1.8.0)
# Requirement already satisfied: pyee>=13.0.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from aiortc>=1.14.0->streamlit-webrtc) (13.0.1)
# Requirement already satisfied: pylibsrtp>=0.10.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from aiortc>=1.14.0->streamlit-webrtc) (1.0.0)
# Requirement already satisfied: pyopenssl>=25.0.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from aiortc>=1.14.0->streamlit-webrtc) (26.2.0)
# Requirement already satisfied: exceptiongroup>=1.0.2 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from anyio>=4.0.0->streamlit) (1.3.1)
# Requirement already satisfied: cffi>=2.0.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from cryptography>=44.0.0->aiortc>=1.14.0->streamlit-webrtc) (2.0.0)
# Requirement already satisfied: pycparser in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from cffi>=2.0.0->cryptography>=44.0.0->aiortc>=1.14.0->streamlit-webrtc) (3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.8.2->pandas<4,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: h11>=0.8 in c:\users\sjija\appdata\local\programs\python\python310\lib\site-packages (from uvicorn>=0.30.0->streamlit) (0.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import streamlit as st
from streamlit_webrtc import webrtc_streamer, VideoProcessorBase, RTCConfiguration
import av
import cv2
import numpy as np

st.set_page_config(page_title="Face Counter", layout="wide")

st.title("📷 Real-Time Face Detection")

RTC_CONFIGURATION = RTCConfiguration(
{
"iceServers": [{"urls": ["stun:stun.l.google.com:19302"]}]
}
)

class FaceDetector(VideoProcessorBase):
    def __init__(self):
        self.face_cascade = cv2.CascadeClassifier(
        cv2.data.haarcascades +
        "haarcascade_frontalface_default.xml"
        )

    def recv(self, frame):
        img = frame.to_ndarray(format="bgr24")

        gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

        faces = self.face_cascade.detectMultiScale(
            gray,
            scaleFactor=1.1,
            minNeighbors=5,
            minSize=(50, 50)
        )

        face_count = len(faces)

        for (x, y, w, h) in faces:
            cv2.rectangle(
                img,
                (x, y),
                (x + w, y + h),
                (0, 255, 0),
                2
            )

        cv2.putText(
            img,
            f"Faces Detected: {face_count}",
            (20, 40),
            cv2.FONT_HERSHEY_SIMPLEX,
            1,
            (0, 255, 0),
            2
        )

        return av.VideoFrame.from_ndarray(
            img,
            format="bgr24"
       )


webrtc_streamer(
key="face-detector",
rtc_configuration=RTC_CONFIGURATION,
video_processor_factory=FaceDetector,
media_stream_constraints={
"video": True,
"audio": False,
},
)
# Out:
# 2026-06-10 10:54:09.130 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-06-10 10:54:09.165 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-06-10 10:54:09.165 WARNING streamlit.runtime.caching.cache_data_api: No runtime found, using MemoryCacheStorageManager
# 2026-06-10 10:54:09.399 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:09.399 No runtime found, using MemoryCacheStorageManager
# 2026-06-10 10:54:10.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:10.100 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:10.454
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\sjija\AppData\Roaming\Python\Python310\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2026-06-10 10:54:10.463 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:10.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:10.465 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:10.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:10.473 Session state does not function when running a script without `streamlit run`
# 2026-06-10 10:54:10.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:10.473 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:10.479 No runtime found, using MemoryCacheStorageManager
# 2026-06-10 10:54:10.484 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:12.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:12.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:12.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:12.381 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:12.393 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-06-10 10:54:12.395 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
